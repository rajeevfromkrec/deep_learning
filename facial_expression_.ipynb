# %% [markdown]
# <a href="https://colab.research.google.com/github/rajeevfromkrec/deep_learning/blob/master/facial_expression_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://kdef.se/download/I.%20KDEF-dyn%20I.zip
# Out:
# --2020-05-30 12:12:07--  https://kdef.se/download/I.%20KDEF-dyn%20I.zip
# Resolving kdef.se (kdef.se)... 46.30.215.36, 2a02:2350:5:104:c900:0:d180:9b4f
# Connecting to kdef.se (kdef.se)|46.30.215.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21094730 (20M) [application/zip]
# Saving to: ‘I. KDEF-dyn I.zip’
#
# I. KDEF-dyn I.zip   100%[===================>]  20.12M  7.04MB/s    in 2.9s
#
# 2020-05-30 12:12:10 (7.04 MB/s) - ‘I. KDEF-dyn I.zip’ saved [21094730/21094730]

# %%
import zipfile

# %%
# !ls
# Out:
# 'I. KDEF-dyn I.zip'   sample_data

# %%
# !wget https://kdef.se/download/KDEF_and_AKDEF.zip
# Out:
# --2020-05-30 12:13:23--  https://kdef.se/download/KDEF_and_AKDEF.zip
# Resolving kdef.se (kdef.se)... 46.30.215.36, 2a02:2350:5:104:c900:0:d180:9b4f
# Connecting to kdef.se (kdef.se)|46.30.215.36|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 524279485 (500M) [application/zip]
# Saving to: ‘KDEF_and_AKDEF.zip’
#
# KDEF_and_AKDEF.zip  100%[===================>] 499.99M  8.68MB/s    in 61s
#
# 2020-05-30 12:14:25 (8.20 MB/s) - ‘KDEF_and_AKDEF.zip’ saved [524279485/524279485]

# %%
zfile= zipfile.ZipFile('KDEF_and_AKDEF.zip')

# %%
zfile.extractall()

# %%
# !ls
# Out:
# 'I. KDEF-dyn I.zip'   KDEF_and_AKDEF   KDEF_and_AKDEF.zip   sample_data

# %%
import os

# %%
os.listdir('KDEF_and_AKDEF/')
# Out:
# ['ReadThis.TXT',
#  'KDEFmap',
#  'ReadThis',
#  'KDEF',
#  'AKDEFmap',
#  'References.txt',
#  'AKDEF']

# %%
cat ReadThis
# Out:
# cat: ReadThis: No such file or directory

# %%
import shutil
# !ls
# Out:
#  dataset	      KDEF_and_AKDEF	   sample_data
# 'I. KDEF-dyn I.zip'   KDEF_and_AKDEF.zip

# %%
# !mkdir dataset

# %%
# !rm -r KDEF_and_AKDEF

# %%
from IPython.display import display, Image
display(Image(filename='./dataset/surprised/surprised153.JPG'))

# %%
os.listdir('./dataset/surprised')
# Out:
# ['surprised297.JPG',
#  'surprised254.JPG',
#  'surprised184.JPG',
#  'surprised238.JPG',
#  'surprised478.JPG',
#  'surprised688.JPG',
#  'surprised450.JPG',
#  'surprised587.JPG',
#  'surprised142.JPG',
#  'surprised504.JPG',
#  'surprised163.JPG',
#  'surprised47.JPG',
#  'surprised566.JPG',
#  'surprised211.JPG',
#  'surprised659.JPG',
#  'surprised138.JPG',
#  'surprised679.JPG',
#  'surprised673.JPG',
#  'surprised257.JPG',
#  'surprised490.JPG',
#  'surprised461.JPG',
#  'surprised584.JPG',
#  'surprised445.JPG',
#  'surprised519.JPG',
#  'surprised509.JPG',
#  'surprised559.JPG',
#  'surprised33.JPG',
#  'surprised405.JPG',
#  'surprised451.JPG',
#  'surprised119.JPG',
#  'surprised689.JPG',
#  'surprised162.JPG',
#  'surprised333.JPG',
#  'surprised395.JPG',
#  'surprised193.JPG',
#  'surprised426.JPG',
#  'surprised94.JPG',
#  'surprised638.JPG',
#  'surprised292.JPG',
#  'surprised466.JPG',
#  'surprised697.JPG',
#  'surprised596.JPG',
#  'surprised538.JPG',
# ...

# %%
# !rm -r ./KDEF_and_AKDEF/KDEF/afraid

# %%
rootdir1=['./KDEF_and_AKDEF/KDEF']

# %%
af = 0
an = 0
di = 0
ha = 0
ne = 0
sa = 0
su = 0

# %%
af = 0
an = 0
di = 0
ha = 0
ne = 0
sa = 0
su = 0

shutil.rmtree('/content/dataset/afraid')
os.mkdir('/content/dataset/afraid')
shutil.rmtree('/content/dataset/angry')
os.mkdir('/content/dataset/angry')
shutil.rmtree('/content/dataset/disgusted')
os.mkdir('/content/dataset/disgusted')
shutil.rmtree('/content/dataset/happy')
os.mkdir('/content/dataset/happy')
shutil.rmtree('/content/dataset/neutral')
os.mkdir('/content/dataset/neutral')
shutil.rmtree('/content/dataset/sad')
os.mkdir('/content/dataset/sad')
shutil.rmtree('/content/dataset/surprised')
os.mkdir('/content/dataset/surprised')
for root, dirs, files in os.walk('./KDEF_and_AKDEF/KDEF', topdown=False):
  for f in files:
    if f.endswith('.JPG'):
      if (f[4:6] == 'AF'):
        old_name=os.path.join(root, f)
        #print(old_name)
        new_name = os.path.join('/content/dataset/afraid/' + "afraid" + str(af) + ".JPG")
        
        shutil.copy(old_name , new_name) 
        #os.rename(os.path.join(root, name), os.path.join(root, new_name))
        af = af + 1

 
      elif (f[4:6] == 'AN'):
        old_name=os.path.join(root, f)
        #print(old_name)
        new_name = os.path.join('/content/dataset/angry/' + "angry" + str(an) + ".JPG")
        
        shutil.copy(old_name , new_name) 
        #os.rename(os.path.join(root, name), os.path.join(root, new_name))
        an = an + 1


      elif (f[4:6] == 'DI'):
        old_name=os.path.join(root, f)
        #print(old_name)
        new_name = os.path.join('/content/dataset/disgusted/' + "disgusted" + str(di) + ".JPG")
 
        shutil.copy(old_name , new_name) 
        #os.rename(os.path.join(root, name), os.path.join(root, new_name))
        di = di + 1

      elif (f[4:6] == 'HA'):
        old_name=os.path.join(root, f)
        #print(old_name)
        new_name = os.path.join('/content/dataset/happy/' + "happy" + str(ha) + ".JPG")
 

        shutil.copy(old_name , new_name) 
        #os.rename(os.path.join(root, name), os.path.join(root, new_name))
        ha = ha + 1


      elif (f[4:6] == 'NE'):
        old_name=os.path.join(root, f)
        #print(old_name)
        new_name = os.path.join('/content/dataset/neutral/' + "neutral" + str(ne) + ".JPG")

        shutil.copy(old_name , new_name) 
        #os.rename(os.path.join(root, name), os.path.join(root, new_name))
        ne = ne + 1


      if (f[4:6] == 'SA'):
        old_name=os.path.join(root, f)
        #print(old_name)
        new_name = os.path.join('/content/dataset/sad/' + "sad" + str(sa) + ".JPG")

        shutil.copy(old_name , new_name) 
        #os.rename(os.path.join(root, name), os.path.join(root, new_name))
        sa = sa + 1


      elif (f[4:6] == 'SU'):
        old_name=os.path.join(root, f)
        #print(old_name)
        new_name = os.path.join('/content/dataset/surprised/' + "surprised" + str(su) + ".JPG")

        shutil.copy(old_name , new_name) 
        #os.rename(os.path.join(root, name), os.path.join(root, new_name))
        su = su + 1
